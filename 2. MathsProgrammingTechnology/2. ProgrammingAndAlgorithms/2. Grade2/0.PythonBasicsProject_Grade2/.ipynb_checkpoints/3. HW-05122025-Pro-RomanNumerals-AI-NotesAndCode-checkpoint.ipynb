# %% [markdown]
# **AI Prompt: Summarize Roman Numerals. Give several examples.
# Explain at the level of a 15 year old who hasn't learnt Roman numerals
# before. Give advantages/disadvantages compared to Indo-Arabic
# numerals.**

# %% [markdown]
# **Roman Numerals: An Introduction**

# %% [markdown]
# Imagine a number system built not on position (like how the "5" in 500 is different from the "5" in 50),
# but on simple building blocks. That’s what Roman numerals are!

# %% [markdown]
# They are based on **seven fixed symbols**, all of which are letters from the Latin alphabet.

# %% [markdown]
# **1. The Seven Symbols and Their Values**

# %% [markdown]
# |Roman Numeral |Value|Note|
# |--------|---------|--------|
# |I|1|Think of it like a tally mark|
# |V|5||
# |X|10||
# |L|50|L, C, D, M are the bigger-value letters|
# |C|100|'C' stands for Centum, the Latin for 100|
# |D|500||
# |M|1,000|'M' stands for Mille, the Latin for 1,000|

# %% [markdown]
# **2. How to Read and Write Roman Numerals (The Rules)**

# %% [markdown]
# You figure out the number by reading the symbols from left to right, and applying two main rules:

# %% [markdown]
# **Rule A: The Addition Rule (Most Common)**

# %% [markdown]
# If a symbol is followed by a symbol of equal or lesser value, you add them together.

# %% [markdown]
# - VI = 5 + 1 = 6

# %% [markdown]
# - XV =  10 + 5 = 15

# %% [markdown]
# - LXX = 50 + 10 + 10 = 70

# %% [markdown]
# **Rule B: The Repetition Limit**

# %% [markdown]
# You can only use the symbols **I, X, C, and M** up to three times in a row. You cannot use V, L, or D more
# than once in a number.

# %% [markdown]
# - Correct: III (3)

# %% [markdown]
# - Incorrect: IIII (You can’t have four I’s—you use the subtraction rule instead!)

# %% [markdown]
# **Rule C: The Subtraction Rule (To avoid repetition)**

# %% [markdown]
# To avoid using four symbols in a row (like IIII for 4), the Romans invented a trick. If a symbol of **smaller
# value** is placed **before** a symbol of **greater value**, you subtract the smaller one from the larger one.

# %% [markdown]
# This rule only applies to these six combinations:

# %% [markdown]
# |Roman Numeral|Calculation|Value|Rule|
# |--------|---------|--------|--------|
# |IV|5 - 1|4|I before V|
# |IX|10 - 1|9|I before X|
# |XL|50 - 10|40|X before L|
# |XC|100 - 10|90|X before C|
# |CD|500 - 100|400|C before D|
# |CM|1000 - 100|900|C before M|

# %% [markdown]
# **3. Examples**

# %% [markdown]
# When reading a long number, you look for those subtractive pairs first, and then add everything else
# up.

# %% [markdown]
# |Number|Breakdown|Roman Numeral|
# |--------|---------|------------|
# |19|10 + (10 - 1)|XIX|
# |44|(50 - 10) + (5 - 1)|XLIV|
# |1492|1000 + 400 + 90 + 2|MCDXCII|
# |2025|1000 + 1000 + 20 + 5|MMXXV|

# %% [markdown]
# **4. Comparison to Indo-Arabic Numerals (1, 2, 3...)**

# %% [markdown]
# The number system you use every day, called Indo-Arabic, is fundamentally different because it is a
# **place value system** (the position of the digit matters).

# %% [markdown]
# **Advantages of Roman Numerals**

# %% [markdown]
# 1. **Formality and Tradition:** They look neat and formal, which is why they are still used in specific
# contexts (Super Bowl titles, dates on buildings, chapters in books, or for monarchs like Queen
# Elizabeth II).

# %% [markdown]
# 2. **Tallying/Counting:** For very basic counting or tallying, the repetitive symbols (I, II, III) are intuitive
# and easy to write quickly.

# %% [markdown]
# **Disadvantages of Roman Numerals**

# %% [markdown]
# 1. **No Zero:** The Romans had no concept of the number zero as a placeholder, making complex math
# impossible.

# %% [markdown]
# 2. **Difficult for Math:** Try multiplying MDCCCLXXXVIII (1888) by XLIX (49). It’s a nightmare! Indo-
# Arabic numerals' place value system ( , then , etc.) makes arithmetic far easier.

# %% [markdown]
# 3. **No Place Value:** Since there's no place value, every new, larger value needs a completely new
# symbol (L for 50, C for 100, D for 500, etc.). This makes large numbers bulky and hard to manage.

# %% [markdown]
# 4. **Limited Range:** Without a zero and simple place-value rules, it's very difficult to represent
# extremely large or negative numbers, and impossible to represent fractions or decimals in a
# practical way.

# %%
# AI Prompt: Using the description in canvas, write python code to convert roman numeral to decimal values and vice versa. Create a new canvas for the code.

"""
Roman Numeral Converter
This script provides two functions for converting between Roman numerals (up to 3999)
and standard decimal integers, based on the rules outlined in the provided documentation.
"""

def roman_to_int(s: str) -> int:
    """
    Converts a Roman numeral string to an integer.
    Uses the subtraction rule (e.g., IV = 4, CM = 900) by checking pairs of symbols.

    Args:
        s (str): The Roman numeral string (e.g., "MCMXCIV").

    Returns:
        int: The corresponding integer value (e.g., 1994).
    """
    # Define the mapping of symbols to values
    roman_map = {
        'I': 1, 'V': 5, 'X': 10, 'L': 50,
        'C': 100, 'D': 500, 'M': 1000
    }

    integer_value = 0
    i = 0

    # Iterate through the Roman numeral string
    while i < len(s):
        # Get the value of the current symbol
        current_value = roman_map[s[i]]

        # Check if there is a next symbol
        if i + 1 < len(s):
            next_value = roman_map[s[i+1]]

            # Check for the subtraction rule (smaller value before larger value)
            # Examples: IV (4), IX (9), XL (40), XC (90), CD (400), CM (900)
            if current_value < next_value:
                # Subtractive pair found: Add the difference and skip the next symbol
                integer_value += (next_value - current_value)
                i += 2  # Move past both the current and the next symbol
                continue

        # If no subtraction is needed (addition rule applies)
        integer_value += current_value
        i += 1

    return integer_value

def int_to_roman(num: int) -> str:
    """
    Converts an integer (1 to 3999) to a Roman numeral string.
    Uses a greedy algorithm with predefined subtractive pairs for efficiency.

    Args:
        num (int): The integer value (e.g., 1994).

    Returns:
        str: The corresponding Roman numeral string (e.g., "MCMXCIV").
    """
    if not 1 <= num <= 3999:
        return "Error: Number must be between 1 and 3999."

    # Define the values and their corresponding Roman symbols,
    # including the subtractive pairs (CM, CD, XC, XL, IX, IV)
    roman_map = [
        (1000, 'M'), (900, 'CM'), (500, 'D'), (400, 'CD'), (100, 'C'),
        (90, 'XC'), (50, 'L'), (40, 'XL'), (10, 'X'), (9, 'IX'),
        (5, 'V'), (4, 'IV'), (1, 'I')
    ]

    roman_numeral = ""

    # Iterate through the map from largest value to smallest
    for value, symbol in roman_map:
        # Check how many times the current value fits into the remaining number
        count = num // value

        # Append the symbol that many times to the result
        roman_numeral += (symbol * count)

        # Subtract the total amount added from the number
        num %= value

        # Stop if the number has been fully converted
        if num == 0:
            break

    return roman_numeral

# --- HOMEWORK PROBLEM SETS (200 Total) ---
# Combined Roman Numeral problems from Homework Set 1 and Set 2

roman_problems = [
    # Homework Set 1 (Problems 1-50)
    'XV', 'III', 'VIII', 'XI', 'XIV', 'XLI', 'LX', 'LXXXV', 'XCI', 'CD',
    'CM', 'CCXX', 'CCCLX', 'DLV', 'DCLX', 'DCCC', 'MXI', 'MCC', 'MCDL', 'MDLX',
    'MDCC', 'MCM', 'MMIV', 'MMDCC', 'MMCM', 'MMMCC', 'MMMCM', 'MMMCCCXL', 'MMMDCLX', 'MMMDCCXCIX',
    'MMMCMXC', 'XXII', 'LII', 'LXXIX', 'CXVII', 'CCXLIX', 'DCCLXII', 'CMXLIX', 'MMLIX', 'MMCMXCIX',
    'MMMCMXLVIII', 'XXXIX', 'CDXXIX', 'DCCLXXVII', 'MCCXXXIV', 'MDLXXX', 'CMXCI', 'MMCDLXIV', 'XXXVI', 'XIX',

    # Homework Set 2 (Problems 1-50)
    'VII', 'XLV', 'XCII', 'CXXIX', 'CDL', 'DCCIV', 'CMXL', 'MI', 'MCCCXXXIII', 'MDCCC',
    'MCMXLVI', 'MMXXXV', 'MMDCCXLIX', 'MMMDLXXXI', 'MMMCMXCIV', 'II', 'XVIII', 'LI', 'XCVII', 'CCXIII',
    'CCCLXIX', 'CDXC', 'DCCLXXXVIII', 'MVI', 'MCMLXXXIX', 'MMCDL', 'MMMDCCC', 'MMMCMIX', 'IV', 'IX',
    'XL', 'LIX', 'CCXL', 'CCCIV', 'CDXLIV', 'DXXVII', 'DCCL', 'MCCCLXVI', 'MMCXX', 'MMDCCCLXXXV',
    'MMMXC', 'MMMCCCXIX', 'MMMCDLXX', 'MMMCMXLI', 'LVIII', 'CCVI', 'DXXX', 'CMXCV', 'MDCXCV', 'MMCCCLV'
]

# Combined Integer problems from Homework Set 1 and Set 2

int_problems = [
    # Homework Set 1 (Problems 51-100)
    13, 27, 3, 4, 9, 18, 29, 40, 55, 83, 99, 104, 149, 200, 350, 400, 488, 512, 666, 799,
    845, 900, 999, 1001, 1250, 1400, 1575, 1660, 1800, 1999, 2024, 2333, 2444, 2500, 2789, 2900,
    2994, 3000, 3300, 3456, 3707, 3888, 3999, 17, 64, 110, 521, 1357, 2603, 30,

    # Homework Set 2 (Problems 51-100)
    2, 6, 19, 33, 49, 62, 78, 84, 109, 144, 187, 230, 315, 450, 509, 622, 707, 888, 940, 1050,
    1111, 1345, 1500, 1678, 1717, 1855, 1960, 2005, 2139, 2222, 2400, 2671, 2890, 3001, 3110, 3225,
    3330, 3404, 3588, 3600, 3749, 3801, 3900, 24, 50, 115, 560, 1090, 2550, 79
]

# --- EXECUTION AND HOMEWORK CHECK ---

print("=" * 60)
print("ROMAN TO DECIMAL CONVERSION CHECK (100 Problems)")
print("=" * 60)

for i, roman in enumerate(roman_problems):
    result = roman_to_int(roman)
    print(f"Problem {i+1:3}: {roman:<12} -> {result}")

print("\n" + "=" * 60)
print("DECIMAL TO ROMAN CONVERSION CHECK (100 Problems)")
print("=" * 60)

for i, num in enumerate(int_problems):
    result = int_to_roman(num)
    # The index here starts at 101 to correspond with the problem numbers in the homework sheets
    print(f"Problem {i+101:3}: {num:<4} -> {result}")

print("=" * 60)
# Out:
# ============================================================
# ROMAN TO DECIMAL CONVERSION CHECK (100 Problems)
# ============================================================
# Problem   1: XV           -> 15
# Problem   2: III          -> 3
# Problem   3: VIII         -> 8
# Problem   4: XI           -> 11
# Problem   5: XIV          -> 14
# Problem   6: XLI          -> 41
# Problem   7: LX           -> 60
# Problem   8: LXXXV        -> 85
# Problem   9: XCI          -> 91
# Problem  10: CD           -> 400
# Problem  11: CM           -> 900
# Problem  12: CCXX         -> 220
# Problem  13: CCCLX        -> 360
# Problem  14: DLV          -> 555
# Problem  15: DCLX         -> 660
# Problem  16: DCCC         -> 800
# Problem  17: MXI          -> 1011
# Problem  18: MCC          -> 1200
# Problem  19: MCDL         -> 1450
# Problem  20: MDLX         -> 1560
# Problem  21: MDCC         -> 1700
# Problem  22: MCM          -> 1900
# Problem  23: MMIV         -> 2004
# Problem  24: MMDCC        -> 2700
# Problem  25: MMCM         -> 2900
# Problem  26: MMMCC        -> 3200
# Problem  27: MMMCM        -> 3900
# Problem  28: MMMCCCXL     -> 3340
# Problem  29: MMMDCLX      -> 3660
# Problem  30: MMMDCCXCIX   -> 3799
# Problem  31: MMMCMXC      -> 3990
# Problem  32: XXII         -> 22
# Problem  33: LII          -> 52
# Problem  34: LXXIX        -> 79
# Problem  35: CXVII        -> 117
# Problem  36: CCXLIX       -> 249
# Problem  37: DCCLXII      -> 762
# Problem  38: CMXLIX       -> 949
# Problem  39: MMLIX        -> 2059
# Problem  40: MMCMXCIX     -> 2999
# Problem  41: MMMCMXLVIII  -> 3948
# Problem  42: XXXIX        -> 39
# Problem  43: CDXXIX       -> 429
# Problem  44: DCCLXXVII    -> 777
# Problem  45: MCCXXXIV     -> 1234
# Problem  46: MDLXXX       -> 1580
# Problem  47: CMXCI        -> 991
# Problem  48: MMCDLXIV     -> 2464
# Problem  49: XXXVI        -> 36
# Problem  50: XIX          -> 19
# Problem  51: VII          -> 7
# Problem  52: XLV          -> 45
# Problem  53: XCII         -> 92
# Problem  54: CXXIX        -> 129
# Problem  55: CDL          -> 450
# Problem  56: DCCIV        -> 704
# Problem  57: CMXL         -> 940
# Problem  58: MI           -> 1001
# Problem  59: MCCCXXXIII   -> 1333
# Problem  60: MDCCC        -> 1800
# Problem  61: MCMXLVI      -> 1946
# Problem  62: MMXXXV       -> 2035
# Problem  63: MMDCCXLIX    -> 2749
# Problem  64: MMMDLXXXI    -> 3581
# Problem  65: MMMCMXCIV    -> 3994
# Problem  66: II           -> 2
# Problem  67: XVIII        -> 18
# Problem  68: LI           -> 51
# Problem  69: XCVII        -> 97
# Problem  70: CCXIII       -> 213
# Problem  71: CCCLXIX      -> 369
# Problem  72: CDXC         -> 490
# Problem  73: DCCLXXXVIII  -> 788
# Problem  74: MVI          -> 1006
# Problem  75: MCMLXXXIX    -> 1989
# Problem  76: MMCDL        -> 2450
# Problem  77: MMMDCCC      -> 3800
# Problem  78: MMMCMIX      -> 3909
# Problem  79: IV           -> 4
# Problem  80: IX           -> 9
# Problem  81: XL           -> 40
# Problem  82: LIX          -> 59
# Problem  83: CCXL         -> 240
# Problem  84: CCCIV        -> 304
# Problem  85: CDXLIV       -> 444
# Problem  86: DXXVII       -> 527
# Problem  87: DCCL         -> 750
# Problem  88: MCCCLXVI     -> 1366
# Problem  89: MMCXX        -> 2120
# Problem  90: MMDCCCLXXXV  -> 2885
# Problem  91: MMMXC        -> 3090
# Problem  92: MMMCCCXIX    -> 3319
# Problem  93: MMMCDLXX     -> 3470
# Problem  94: MMMCMXLI     -> 3941
# Problem  95: LVIII        -> 58
# Problem  96: CCVI         -> 206
# Problem  97: DXXX         -> 530
# Problem  98: CMXCV        -> 995
# Problem  99: MDCXCV       -> 1695
# Problem 100: MMCCCLV      -> 2355
#
# ============================================================
# DECIMAL TO ROMAN CONVERSION CHECK (100 Problems)
# ============================================================
# Problem 101: 13   -> XIII
# Problem 102: 27   -> XXVII
# Problem 103: 3    -> III
# Problem 104: 4    -> IV
# Problem 105: 9    -> IX
# Problem 106: 18   -> XVIII
# Problem 107: 29   -> XXIX
# Problem 108: 40   -> XL
# Problem 109: 55   -> LV
# Problem 110: 83   -> LXXXIII
# Problem 111: 99   -> XCIX
# Problem 112: 104  -> CIV
# Problem 113: 149  -> CXLIX
# Problem 114: 200  -> CC
# Problem 115: 350  -> CCCL
# Problem 116: 400  -> CD
# Problem 117: 488  -> CDLXXXVIII
# Problem 118: 512  -> DXII
# Problem 119: 666  -> DCLXVI
# Problem 120: 799  -> DCCXCIX
# Problem 121: 845  -> DCCCXLV
# Problem 122: 900  -> CM
# Problem 123: 999  -> CMXCIX
# Problem 124: 1001 -> MI
# Problem 125: 1250 -> MCCL
# Problem 126: 1400 -> MCD
# Problem 127: 1575 -> MDLXXV
# Problem 128: 1660 -> MDCLX
# Problem 129: 1800 -> MDCCC
# Problem 130: 1999 -> MCMXCIX
# Problem 131: 2024 -> MMXXIV
# Problem 132: 2333 -> MMCCCXXXIII
# Problem 133: 2444 -> MMCDXLIV
# Problem 134: 2500 -> MMD
# Problem 135: 2789 -> MMDCCLXXXIX
# Problem 136: 2900 -> MMCM
# Problem 137: 2994 -> MMCMXCIV
# Problem 138: 3000 -> MMM
# Problem 139: 3300 -> MMMCCC
# Problem 140: 3456 -> MMMCDLVI
# Problem 141: 3707 -> MMMDCCVII
# Problem 142: 3888 -> MMMDCCCLXXXVIII
# Problem 143: 3999 -> MMMCMXCIX
# Problem 144: 17   -> XVII
# Problem 145: 64   -> LXIV
# Problem 146: 110  -> CX
# Problem 147: 521  -> DXXI
# Problem 148: 1357 -> MCCCLVII
# Problem 149: 2603 -> MMDCIII
# Problem 150: 30   -> XXX
# Problem 151: 2    -> II
# Problem 152: 6    -> VI
# Problem 153: 19   -> XIX
# Problem 154: 33   -> XXXIII
# Problem 155: 49   -> XLIX
# Problem 156: 62   -> LXII
# Problem 157: 78   -> LXXVIII
# Problem 158: 84   -> LXXXIV
# Problem 159: 109  -> CIX
# Problem 160: 144  -> CXLIV
# Problem 161: 187  -> CLXXXVII
# Problem 162: 230  -> CCXXX
# Problem 163: 315  -> CCCXV
# Problem 164: 450  -> CDL
# Problem 165: 509  -> DIX
# Problem 166: 622  -> DCXXII
# Problem 167: 707  -> DCCVII
# Problem 168: 888  -> DCCCLXXXVIII
# Problem 169: 940  -> CMXL
# Problem 170: 1050 -> ML
# Problem 171: 1111 -> MCXI
# Problem 172: 1345 -> MCCCXLV
# Problem 173: 1500 -> MD
# Problem 174: 1678 -> MDCLXXVIII
# Problem 175: 1717 -> MDCCXVII
# Problem 176: 1855 -> MDCCCLV
# Problem 177: 1960 -> MCMLX
# Problem 178: 2005 -> MMV
# Problem 179: 2139 -> MMCXXXIX
# Problem 180: 2222 -> MMCCXXII
# Problem 181: 2400 -> MMCD
# Problem 182: 2671 -> MMDCLXXI
# Problem 183: 2890 -> MMDCCCXC
# Problem 184: 3001 -> MMMI
# Problem 185: 3110 -> MMMCX
# Problem 186: 3225 -> MMMCCXXV
# Problem 187: 3330 -> MMMCCCXXX
# Problem 188: 3404 -> MMMCDIV
# Problem 189: 3588 -> MMMDLXXXVIII
# Problem 190: 3600 -> MMMDC
# Problem 191: 3749 -> MMMDCCXLIX
# Problem 192: 3801 -> MMMDCCCI
# Problem 193: 3900 -> MMMCM
# Problem 194: 24   -> XXIV
# Problem 195: 50   -> L
# Problem 196: 115  -> CXV
# Problem 197: 560  -> DLX
# Problem 198: 1090 -> MXC
# Problem 199: 2550 -> MMDL
# Problem 200: 79   -> LXXIX
# ============================================================

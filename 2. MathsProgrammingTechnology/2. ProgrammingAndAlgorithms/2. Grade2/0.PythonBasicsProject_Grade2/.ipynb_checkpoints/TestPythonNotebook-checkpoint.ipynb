# %% [markdown]
# # Test
# This is an example of python notebook

# %% [markdown]
# # x = 43; print(x)

# %% [raw]
# # x = 43; print(x)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.randint(0, 10, 5); y = np.random.randint(0, 10, 5);
plt.plot(x,y);
